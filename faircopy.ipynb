# %%
from MultipleFunctions import multiplefunctions

# %%
multiplefunctions.OddEven()
# Out:
# Enter the number: 21
# Odd Number
# 'Odd Number'

# %%
multiplefunctions.BMICal()
# Out:
# Enter the BMI Intex: 21
# Normal weight
# 'Normal weight'
