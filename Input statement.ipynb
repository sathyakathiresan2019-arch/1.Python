# %%
num1=input("Enter the num1:")
# Out:
# Enter the num1: 50

# %%
num2=input("Enter the num2:")
# Out:
# Enter the num2: 50

# %%
add=num1+num2

# %%
print(add)
# Out:
# 5050

# %%
num1=int(input("Enter the num1:"))
# Out:
# Enter the num1: 50

# %%
num2=int(input("Enter the num2:"))
# Out:
# Enter the num2: 65

# %%
add=num1+num2

# %%
print(add)
# Out:
# 115

# %%
name=input("Enter your name:")
# Out:
# Enter your name: Sathya kathiresan

# %%
name2=input('Enter your name:')
# Out:
# Enter your name: Sathya.K
