# %%
class calculator():
    def add(a,b):
        addition=a+b
        return addition
        
    def sub(a,b):
        subtraction=a-b
        return subtraction

# %%
calculator.sub(1,1)
# Out:
# 0

# %%
class
