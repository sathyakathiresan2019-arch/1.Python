# %%
#if
age=int(input("Enter the age:"))
# Out:
# Enter the age: 18

# %%
if(age==18):
    print("ADULT")
# Out:
# ADULT

# %%
age=int(input("Enter the age:"))
# Out:
# Enter the age: 18

# %%
if(age<=18):
    print("Adult")
else:
    print("children")
# Out:
# Adult

# %%
age=int(input("Enter the age:"))
# Out:
# Enter the age: 10

# %%
if(age<18):
    print("Children")
else:
    print('Adult')
# Out:
# Children

# %%
age=int(input("Enter the age:"))
# Out:
# Enter the age: 65

# %%
if(age<18):
    print("Children")
elif(age<35):
    print('Adult')
elif(age<59):
    print('citizen')
else:
    print('senior citizen')
# Out:
# senior citizen

# %%
Mark=int(input("Enter the mark:"))
# Out:
# Enter the mark: 91

# %%
if(Mark<40):
    print("Fail")
elif(Mark<60):
    print('B Grade')
elif(Mark<80):
    print('A Grade')
elif(Mark<90):
    print('A+ Grade')
else:
    print('Distinction')
# Out:
# Distinction
